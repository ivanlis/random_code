# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(style="whitegrid")
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import re

# %%
#basePath = "D:\\development\\m3_stuff\\m3_traditional2\\M3\\branches\\M3Hybrid64\\m3\\M3\\data\\ggfx"
basePath="C:\\Program Files\\Innovalia Metrology\\M3\\data\\ggfx"

# %%
leadDeviations = pd.read_csv(os.path.join(basePath, '9_265_L_0_R.txt'), delimiter=' ', header=None, skiprows=8, 
                            names=['x', 'y'])

# %%
sns.relplot(kind='line', x='x', y='y', data=leadDeviations, height=5, aspect=2)
